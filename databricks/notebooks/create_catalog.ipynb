# %% [markdown]
# ## Crear catalog UrbanThreads

# %%
# %sql
CREATE CATALOG IF NOT EXISTS `urban_catalog`;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS `urban_catalog`.`bronze`
MANAGED LOCATION 'abfss://lakehouse@dlurbanstorage.dfs.core.windows.net/bronze/urban_catalog';
CREATE SCHEMA IF NOT EXISTS `urban_catalog`.`silver`;
CREATE SCHEMA IF NOT EXISTS `urban_catalog`.`gold`;
