# %% [markdown]
# ### Load Dataframes

# %%
# %py
df_dim_categoria = spark.read.table("urban_catalog.bronze.categoria")

# %%
# %py
df_dim_producto = spark.read.table("urban_catalog.bronze.producto")

# %%
# %py
df_fact_venta_encabezado = spark.read.table("urban_catalog.bronze.ventaEncabezado")

# %%
# %py
df_fact_venta_detalles = spark.read.table("urban_catalog.bronze.ventaDetalle")

# %% [markdown]
# ### Create tables

# %%
# %py
df_dim_categoria.write.mode("overwrite").format("delta").saveAsTable("urban_catalog.silver.categoria_raw")

# %%
# %py
df_dim_producto.write.mode("overwrite").format("delta").saveAsTable("urban_catalog.silver.producto_raw")

# %%
# %py
df_fact_venta_encabezado.write.mode("overwrite").format("delta").saveAsTable("urban_catalog.silver.ventaEncabezado_raw")

# %%
# %py
df_fact_venta_detalles.write.mode("overwrite").format("delta").saveAsTable("urban_catalog.silver.ventaDetalle_raw")
